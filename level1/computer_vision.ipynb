# %% [markdown]
# import open cv

# %%
import cv2
import numpy as np 
import matplotlib.pyplot as plt

# %%
a=cv2.imread('froggy.jpg')
print(a.shape)
# Out:
# (4032, 3024, 3)

# %%
plt.imshow(a)

# %%
b=cv2.cvtColor(a,cv2.COLOR_BGR2GRAY)
plt.imshow(b,cmap='gray')

# %%
c=cv2.cvtColor(a,cv2.COLOR_BGR2GRAY)
plt.imshow(c)

# %%
d=cv2.imread(r'C:\Users\rites\OneDrive\Documents\python_data_analytics\level1\froggy.jpg')
plt.imshow(d)

# %%
#resize by resolution
print(a.shape)
ar=cv2.resize(c,(1600,500) )
plt.imshow(ar)
# Out:
# (4032, 3024, 3)

# %%
#resize by scale
cscaled=cv2.resize(c,0,fx=0.5,fy=0.5)
plt.imshow(cscaled)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[46], line 2
#       1 #resize by scale
# ----> 2 cscaled=cv2.resize(c,0,fx=0.5,fy=0.5)
#       3 plt.imshow(cscaled)
#
# error: OpenCV(4.7.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - Can't parse 'dsize'. Input argument doesn't provide sequence protocol
# >  - Can't parse 'dsize'. Input argument doesn't provide sequence protocol

# %%
#apply blur 
cblur=cv2.GaussianBlur(c,(11,51),0)
plt.imshow(cblur)

# %%
#apply edge detection
cgray=cv2.cvtColor(c,cv2.COLOR_RGB2GRAY)
